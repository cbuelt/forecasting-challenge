# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import date, timedelta, datetime
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_pinball_loss
from sklearn.linear_model import QuantileRegressor
from matplotlib import pyplot as plt
from numpy.lib.stride_tricks import sliding_window_view
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow_addons.losses import pinball_loss
from sklearn.metrics import mean_pinball_loss
import math
from scipy import stats

# %%
quantiles = [0.025, 0.25, 0.5, 0.75, 0.975]
horizons = [1,2,3,4,5]

# %% [markdown]
# # Get data

# %%
current_day = datetime.today()
data = yf.download("^GDAXI", start="2000-01-01", end=current_day)["Adj Close"]
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2000-01-03     6750.759766
# 2000-01-04     6586.950195
# 2000-01-05     6502.069824
# 2000-01-06     6474.919922
# 2000-01-07     6780.959961
#                   ...
# 2021-12-10    15623.309570
# 2021-12-13    15621.719727
# 2021-12-14    15453.559570
# 2021-12-15    15476.349609
# 2021-12-16    15713.669922
# Name: Adj Close, Length: 5573, dtype: float64

# %% [markdown]
# ## Data preparation
#
# Add all five horizons as a predictor

# %%
data_prep = pd.DataFrame(data)
data_prep["log_return"] = 100 * (np.log(data_prep) - np.log(data_prep.shift(1)))

for horizon in range(1,6):
    data_prep[horizon] = 100 * (np.log(data_prep["Adj Close"]) - np.log(data_prep["Adj Close"].shift(horizon)))
    data_prep[horizon] = data_prep[horizon].shift(-horizon)

#Drop CLose
data_prep.drop("Adj Close", axis = 1, inplace = True)

# %% [markdown]
# ## Add positional encoding

# %%
pos_enc = pd.DataFrame(index = data_prep.index)
#Year encoding
pos_enc["Year"] = pos_enc.index.year
pos_enc["n_days"] = 365
pos_enc.loc[(pos_enc["Year"]-2000)%4 ==0,"n_days"] = 366
pos_enc["Year"] = pos_enc["Year"] - pos_enc["Year"].min()
#Positional encoding
cos_encoding = np.cos(2*math.pi*pos_enc.index.dayofyear/pos_enc["n_days"])
data_prep.insert(1, "cos_enc", cos_encoding)

# %% [markdown]
# ## Add return of other indices

# %%
#Through time difference it is the previous day course
nas = yf.download("^IXIC", start="2000-01-01", end=current_day)["Adj Close"]
nas_ret = np.log(nas) - np.log(nas.shift(1))
data_prep.insert(2, "nasdaq", nas_ret)
# Out:
# [*********************100%***********************]  1 of 1 completed
#             log_return   cos_enc    nasdaq         1         2         3  \
# Date
# 2000-01-03         NaN  0.998674  0.015082 -2.456461 -3.753450 -4.171882
# 2000-01-04   -2.456461  0.997643 -0.057146 -1.296989 -1.715421  2.902823
# 2000-01-05   -1.296989  0.996318 -0.006209 -0.418432  4.199812  6.309258
# 2000-01-06   -0.418432  0.994700 -0.039562  4.618244  6.727690  6.231625
# 2000-01-07    4.618244  0.992788  0.040872  2.109446  1.613381  1.925754
# ...                ...       ...       ...       ...       ...       ...
# 2021-12-10   -0.102040  0.935368  0.007270 -0.010177 -1.092463 -0.945098
# 2021-12-13   -0.010177  0.952378 -0.014001 -1.082287 -0.934921  0.603359
# 2021-12-14   -1.082287  0.957485 -0.011461  0.147366  1.685646       NaN
# 2021-12-15    0.147366  0.962309  0.021293  1.538280       NaN       NaN
# 2021-12-16    1.538280  0.966848       NaN       NaN       NaN       NaN
#
#                    4         5
# Date
# 2000-01-03  0.446362  2.555809
# 2000-01-04  5.012269  4.516204
# 2000-01-05  5.813193  6.125566
# 2000-01-06  6.543998  7.166548
# 2000-01-07  2.548304  5.623600
# ...              ...       ...
# 2021-12-10  0.593183       NaN
# 2021-12-13       NaN       NaN
# 2021-12-14       NaN       NaN
# 2021-12-15       NaN       NaN
# 2021-12-16       NaN       NaN
#
# [5573 rows x 8 columns]

# %%
window_size = 128
test_size = 360
val_size = 360

pred_data = data_prep[-window_size:]

#Drop Nans
data_prep.dropna(inplace = True)

test_data = data_prep[-(test_size+window_size-1):]
val_data = data_prep[-(val_size+test_size+window_size-1):-test_size]
train_data = data_prep[:-(val_size+test_size)]

# %%
train_mean = train_data.mean()
train_sd = train_data.std()

# %%
def normalize(data, mean = train_mean, sd = train_sd):
    return (data-train_mean)/train_sd

# %%
train_data = normalize(train_data)
val_data = normalize(val_data)
test_data = normalize(test_data)
pred_data = normalize(pred_data)

# %%
def convert_data(data, window_size = window_size):
    window = sliding_window_view(data.to_numpy(), window_size, axis = 0)
    window = np.swapaxes(window, 1,2)
    features = window[:,:,0:3]
    X = features
    Y = np.expand_dims(window[:,-1,3:],2)
    return X,Y

# %%
x_train, y_train = convert_data(train_data)
x_val, y_val = convert_data(val_data)
x_test, y_test = convert_data(test_data)

# %% [markdown]
# ## Build model

# %%
def model(dropout_rate = 0.1, window_size = window_size):
    
    #Define parameters
    filters = 16
    kernel_size = 2
    dilation_rates = [2**i for i in range(7)]
    
    #Define Inputs
    input_features = Input(shape=(window_size, 3))

    x = input_features
    #Base layers
    skips = []
    for dilation in dilation_rates:
        #Preprocessing layer
        x = Conv1D(16, 1, padding='same', activation='relu')(x) 
        #Dilated convolution
        z = Conv1D(filters, kernel_size, activation="relu", padding="causal", dilation_rate=dilation)(x)
        #Postprocessing
        z = Conv1D(16, 1, padding='same', activation='relu')(z)
        #Residual connection
        x = Add()([x,z])

    #Fully Connected Layer
    out = Conv1D(32, 1, padding = "same")(x)
    out = Dropout(dropout_rate)(out)
    out = Conv1D(1, 1, activation="linear")(out)
    out = Flatten()(out)
    out = Dense(5)(out)
    cnn = Model(input_features, out)
    return cnn

# %%
cnn = model()
cnn.summary()
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           [(None, 128, 3)]     0
# __________________________________________________________________________________________________
# conv1d_207 (Conv1D)             (None, 128, 16)      64          input_10[0][0]
# __________________________________________________________________________________________________
# conv1d_208 (Conv1D)             (None, 128, 16)      528         conv1d_207[0][0]
# __________________________________________________________________________________________________
# conv1d_209 (Conv1D)             (None, 128, 16)      272         conv1d_208[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 128, 16)      0           conv1d_207[0][0]
#                                                                  conv1d_209[0][0]
# __________________________________________________________________________________________________
# conv1d_210 (Conv1D)             (None, 128, 16)      272         add_63[0][0]
# __________________________________________________________________________________________________
# conv1d_211 (Conv1D)             (None, 128, 16)      528         conv1d_210[0][0]
# __________________________________________________________________________________________________
# conv1d_212 (Conv1D)             (None, 128, 16)      272         conv1d_211[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 128, 16)      0           conv1d_210[0][0]
#                                                                  conv1d_212[0][0]
# __________________________________________________________________________________________________
# conv1d_213 (Conv1D)             (None, 128, 16)      272         add_64[0][0]
# __________________________________________________________________________________________________
# conv1d_214 (Conv1D)             (None, 128, 16)      528         conv1d_213[0][0]
# __________________________________________________________________________________________________
# conv1d_215 (Conv1D)             (None, 128, 16)      272         conv1d_214[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 128, 16)      0           conv1d_213[0][0]
#                                                                  conv1d_215[0][0]
# __________________________________________________________________________________________________
# conv1d_216 (Conv1D)             (None, 128, 16)      272         add_65[0][0]
# __________________________________________________________________________________________________
# conv1d_217 (Conv1D)             (None, 128, 16)      528         conv1d_216[0][0]
# __________________________________________________________________________________________________
# conv1d_218 (Conv1D)             (None, 128, 16)      272         conv1d_217[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 128, 16)      0           conv1d_216[0][0]
#                                                                  conv1d_218[0][0]
# __________________________________________________________________________________________________
# conv1d_219 (Conv1D)             (None, 128, 16)      272         add_66[0][0]
# __________________________________________________________________________________________________
# conv1d_220 (Conv1D)             (None, 128, 16)      528         conv1d_219[0][0]
# __________________________________________________________________________________________________
# conv1d_221 (Conv1D)             (None, 128, 16)      272         conv1d_220[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 128, 16)      0           conv1d_219[0][0]
#                                                                  conv1d_221[0][0]
# __________________________________________________________________________________________________
# conv1d_222 (Conv1D)             (None, 128, 16)      272         add_67[0][0]
# __________________________________________________________________________________________________
# conv1d_223 (Conv1D)             (None, 128, 16)      528         conv1d_222[0][0]
# __________________________________________________________________________________________________
# conv1d_224 (Conv1D)             (None, 128, 16)      272         conv1d_223[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 128, 16)      0           conv1d_222[0][0]
#                                                                  conv1d_224[0][0]
# __________________________________________________________________________________________________
# conv1d_225 (Conv1D)             (None, 128, 16)      272         add_68[0][0]
# __________________________________________________________________________________________________
# conv1d_226 (Conv1D)             (None, 128, 16)      528         conv1d_225[0][0]
# __________________________________________________________________________________________________
# conv1d_227 (Conv1D)             (None, 128, 16)      272         conv1d_226[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 128, 16)      0           conv1d_225[0][0]
#                                                                  conv1d_227[0][0]
# __________________________________________________________________________________________________
# conv1d_228 (Conv1D)             (None, 128, 32)      544         add_69[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 32)      0           conv1d_228[0][0]
# __________________________________________________________________________________________________
# conv1d_229 (Conv1D)             (None, 128, 1)       33          dropout_9[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 128)          0           conv1d_229[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 5)            645         flatten_9[0][0]
# ==================================================================================================
# Total params: 8,518
# Trainable params: 8,518
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
BATCH_SIZE = 128
EPOCHS = 100
learning_rate = 0.05
optimizer = tf.keras.optimizers.Adadelta(learning_rate = learning_rate)

#Early stopping
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 4, min_delta = 1e-5)

# %%
def train_model(model, optimizer, x_train, y_train, x_val, y_val, quantile, BATCH_SIZE = BATCH_SIZE, EPOCHS = EPOCHS, callback = callback, verbose = False):
    model.compile(optimizer = optimizer,  loss = lambda true,pred: pinball_loss(true, pred, tau = quantile))
    history = model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = EPOCHS, batch_size = BATCH_SIZE, shuffle=True,
        callbacks = [callback], verbose = verbose)
    return model

# %%
def train_all_models(x_train, y_train, x_val, y_val, quantiles = quantiles, optimizer = optimizer, batch_size = BATCH_SIZE, epochs = EPOCHS, callback = callback):
    models = dict()
    for quantile in quantiles:
        cnn = model()
        cnn = train_model(cnn, optimizer, x_train, y_train, x_val, y_val, quantile)
        print("Training finished for quantile {}".format(quantile))
        models[quantile] = cnn
    return models

# %%
models = train_all_models(x_train, y_train, x_val, y_val)
# Out:
# Training finished for quantile 0.025
# Training finished for quantile 0.25
# Training finished for quantile 0.5
# Training finished for quantile 0.75
# Training finished for quantile 0.975

# %% [markdown]
# ## Predict test data

# %%
predictions = dict()
for quantile in quantiles:
    pred = models[quantile].predict(x_test)
    predictions[quantile]=pred

# %% [markdown]
# ### Evaluate Loss

# %%
true_values = np.squeeze(y_test)
total_loss = 0
for quantile in quantiles:
    pred = np.squeeze(predictions[quantile])
    loss = mean_pinball_loss(true_values, pred, alpha = quantile)
    total_loss += loss
    print("Pinball Loss for quantile {}: \t {}".format(quantile, loss))
print("Pinball Loss total: {}".format(total_loss/len(quantiles)))
# Out:
# Pinball Loss for quantile 0.025: 	 0.05846508066769779
# Pinball Loss for quantile 0.25: 	 0.22400526280900485
# Pinball Loss for quantile 0.5: 	 0.24207361870260052
# Pinball Loss for quantile 0.75: 	 0.20731476775881666
# Pinball Loss for quantile 0.975: 	 0.049336992694329854
# Pinball Loss total: 0.15623914452648993

# %% [markdown]
# ### Test plausability

# %%
true_values = np.squeeze(y_test)
for quantile in quantiles:
    pred = np.squeeze(predictions[quantile])
    q_smaller = (pred >= true_values).sum()
    emp_quant = q_smaller / true_values.size
    print("Quantile met for quantile = {}: \t {} %".format(quantile, np.round(emp_quant,4)*100))
# Out:
# Quantile met for quantile = 0.025: 	 1.0 %
# Quantile met for quantile = 0.25: 	 14.219999999999999 %
# Quantile met for quantile = 0.5: 	 49.28 %
# Quantile met for quantile = 0.75: 	 81.5 %
# Quantile met for quantile = 0.975: 	 98.28 %

# %% [markdown]
# ### Plot predictions

# %%
fig, axs = plt.subplots(3,2,figsize = (20,15))
axs = axs.ravel()
length = len(test_data)-window_size+1

for cnt,horizon in enumerate(horizons):

    sns.lineplot(x = test_data.iloc[-length:].index, y = horizon, data = test_data.iloc[-length:], ax = axs[cnt])
    for quantile in quantiles:
        sns.lineplot(x = test_data.iloc[-length:].index, y = predictions[quantile][:,cnt], ax = axs[cnt])
    axs[cnt].set_title("Quantile prediction for horizon: {}".format(horizon), size = 15)
    labels = ["True values",0.025, 0.25, 0.5, 0.75, 0.975]
    axs[cnt].legend(labels)

# %% [markdown]
# ## Predict new data

# %%
x_train, y_train = convert_data(train_data.append(val_data))
x_pred, y_pred = convert_data(pred_data)

# %%
models = train_all_models(x_train, y_train, x_test, y_test)
# Out:
# Training finished for quantile 0.025
# Training finished for quantile 0.25
# Training finished for quantile 0.5
# Training finished for quantile 0.75
# Training finished for quantile 0.975

# %%
predictions = dict()
for quantile in quantiles:
    pred = models[quantile].predict(x_pred)
    predictions[quantile]=pred
# Out:
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021C703BB700> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 17 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000021C77762A60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
future_pred = np.zeros(shape = (5,5))
for cnt,quantile in enumerate(quantiles):
    future_pred[cnt] = models[quantile].predict(x_pred)
#Renormalize
for h in range(5):
    future_pred[:,h] = future_pred[:,h]*train_sd[h+1] + train_mean[h+1]

# %%
df_horizons = [1,2,5,6,7]
final_prediction = pd.DataFrame(columns = ["forecast_date","target","horizon","q0.025","q0.25","q0.5","q0.75","q0.975"])
final_prediction["forecast_date"] = [(current_day).strftime("%Y-%m-%d") for x in df_horizons]
final_prediction["horizon"] = ["{} day".format(x) for x in df_horizons]
final_prediction["target"] = "DAX"

for cnt, quantile in enumerate(quantiles):
    final_prediction["q{}".format(quantile)] = future_pred[cnt,:]

# %%
final_prediction
# Out:
#   forecast_date target horizon    q0.025     q0.25      q0.5     q0.75  \
# 0    2021-12-15    DAX   1 day -2.753596 -0.532687  0.046341  0.830778
# 1    2021-12-15    DAX   2 day -4.099766 -0.460600  0.146977  1.096627
# 2    2021-12-15    DAX   5 day -4.876529 -1.040079  0.144620  1.285179
# 3    2021-12-15    DAX   6 day -5.343367 -1.359924  0.227232  1.391939
# 4    2021-12-15    DAX   7 day -6.663001 -0.564845  0.286785  1.520046
#
#      q0.975
# 0  1.980707
# 1  3.017717
# 2  2.737138
# 3  3.762908
# 4  4.325353

# %% [markdown]
# ## Save final prediction

# %%
current_date = date.today().strftime("%Y-%m-%d")
final_prediction.to_pickle("../evaluation/predictions/single/DAX_{}".format(current_date))
