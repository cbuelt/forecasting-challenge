# %%
import pandas as pd
import numpy as np
from datetime import date, timedelta, datetime

# %% [markdown]
# # Aggregate data

# %%
#Load predictions
current_date = date.today().strftime("%Y-%m-%d")
targets = ["DAX","temperature", "wind"]

# %%
final_submission = pd.DataFrame(columns = ["forecast_date","target","horizon","q0.025","q0.25","q0.5","q0.75","q0.975"])
for target in targets:
    data = pd.read_pickle("single/{}_2021-10-20".format(target))
    final_submission = final_submission.append(data)
final_submission = final_submission.reset_index().drop("index", axis = 1)

# %%
final_submission
# Out:
#    forecast_date       target  horizon     q0.025     q0.25      q0.5  \
# 0     2021-10-20          DAX    1 day  -2.739411 -0.650267  0.114251
# 1     2021-10-20          DAX    2 day  -9.585247 -2.174104  0.343736
# 2     2021-10-20          DAX    5 day  -9.802836 -2.073265  0.630373
# 3     2021-10-20          DAX    6 day -12.600079 -3.400104  0.881958
# 4     2021-10-20          DAX    7 day -15.115002 -4.352365  1.174757
# 5     2021-10-20  temperature  36 hour   13.11425     13.91    14.415
# 6     2021-10-20  temperature  48 hour    3.86725    6.3375      7.45
# 7     2021-10-20  temperature  60 hour    9.75275   10.6925    11.325
# 8     2021-10-20  temperature  72 hour      2.565     4.245       5.6
# 9     2021-10-20  temperature  84 hour   10.52275   11.7375    12.145
# 10    2021-10-20         wind  36 hour    25.1055    28.225    28.975
# 11    2021-10-20         wind  48 hour     1.7945     3.765     6.415
# 12    2021-10-20         wind  60 hour    9.26025   16.3325     19.07
# 13    2021-10-20         wind  72 hour      1.585    6.3875     7.535
# 14    2021-10-20         wind  84 hour    1.06325    3.8575      6.66
#
#        q0.75     q0.975
# 0   1.129395   3.340193
# 1   2.347618   7.745867
# 2   3.970054   5.013111
# 3   4.590085    9.05376
# 4    6.15986  17.666272
# 5    14.9025     15.605
# 6      8.775   10.25125
# 7     11.615   13.38175
# 8      6.825     8.3285
# 9     12.575     13.276
# 10   31.7075   33.87375
# 11     9.385   14.06875
# 12     21.94   25.42875
# 13    9.3575    11.8815
# 14    8.6875   13.27375

# %% [markdown]
# # Save submission

# %% [markdown]
# ## Check submission

# %%
from check_submission import check_df
check_df(final_submission)
# Out:
# Start checking...
# ---------------------------
# Checking the Columns...
# Checking type of columns...
# Checking if the Dates make sense...
# ----WARNING: Forecast date should not be in the past
# Checking targets...
# Checking quantiles...
# ---------------------------
# Looks good!

# %%
final_submission.to_csv("aggregated/complete_forecast_{}.csv".format(current_date), index = False)
