# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, datetime, timedelta
import re

# %% [markdown]
# ## Read weekly data

# %%
start_date = date(2021, 10 ,27)
dates = [start_date+timedelta(x) for x in range(7,7*16,7)]
raw_data = pd.read_csv("weekly/evaluation_{}.csv".format(start_date.strftime("%Y%m%d")))

# %%
for date in dates:
    try:
        raw_data = raw_data.append(pd.read_csv("weekly/evaluation_{}.csv".format(date.strftime("%Y%m%d"))))
    except:
        print(date.strftime("%Y-%m-%d")+" Not available")
# Out:
# 2021-12-29 Not available
# 2022-01-05 Not available
# 2022-01-26 Not available
# 2022-02-02 Not available
# 2022-02-09 Not available

# %%
raw_data
# Out:
#               model       target  horizon forecast_date    q0.025     q0.25  \
# 0         AryaStark          DAX    1 day    2021-10-27 -2.294067 -0.422822
# 1      JabbaTheHutt          DAX    1 day    2021-10-27 -2.520820 -0.421760
# 2          DougJudy          DAX    1 day    2021-10-27  0.098211  0.098224
# 3           KyloRen          DAX    1 day    2021-10-27 -2.493657 -0.441905
# 4           HanSolo          DAX    1 day    2021-10-27 -1.842954 -0.568223
# ..              ...          ...      ...           ...       ...       ...
# 415    JabbaTheHutt  temperature  84 hour    2022-01-19       NaN       NaN
# 416      RossGeller  temperature  84 hour    2022-01-19       NaN       NaN
# 417    UglyNakedGuy  temperature  84 hour    2022-01-19       NaN       NaN
# 418  wind_benchmark  temperature  84 hour    2022-01-19       NaN       NaN
# 419       wind_EMOS  temperature  84 hour    2022-01-19       NaN       NaN
#
#          q0.5     q0.75    q0.975     value  qscore_q0.025  qscore_q0.25  \
# 0    0.051950  0.540928  2.105637 -0.060375       0.111685      0.181223
# 1    0.075880  0.658580  2.093510 -0.060375       0.123022      0.180693
# 2    0.098231  0.098238  0.098250 -0.060375       0.309243      0.237898
# 3    0.084151  0.639838  2.230883 -0.060375       0.121664      0.190765
# 4    0.064408  0.764962  2.687890 -0.060375       0.089129      0.253924
# ..        ...       ...       ...       ...            ...           ...
# 415       NaN       NaN       NaN       NaN            NaN           NaN
# 416       NaN       NaN       NaN       NaN            NaN           NaN
# 417       NaN       NaN       NaN       NaN            NaN           NaN
# 418       NaN       NaN       NaN       NaN            NaN           NaN
# 419       NaN       NaN       NaN       NaN            NaN           NaN
#
#      qscore_q0.5  qscore_q0.75  qscore_q0.975  mean_qscore        ae  \
# 0       0.112325      0.300651       0.108301     0.162837  0.112325
# 1       0.136255      0.359477       0.107694     0.181428  0.136255
# 2       0.158606      0.079306       0.007931     0.158597  0.158606
# 3       0.144526      0.350106       0.114563     0.184325  0.144526
# 4       0.124782      0.412668       0.137413     0.203583  0.124782
# ..           ...           ...            ...          ...       ...
# 415          NaN           NaN            NaN          NaN       NaN
# 416          NaN           NaN            NaN          NaN       NaN
# 417          NaN           NaN            NaN          NaN       NaN
# 418          NaN           NaN            NaN          NaN       NaN
# 419          NaN           NaN            NaN          NaN       NaN
#
#     interval_coverage_0.5 interval_coverage_0.95  scores_imputed
# 0                    True                   True           False
# 1                    True                   True           False
# 2                   False                  False           False
# 3                    True                   True           False
# 4                    True                   True           False
# ..                    ...                    ...             ...
# 415                 False                  False            True
# 416                 False                  False            True
# 417                 False                  False            True
# 418                 False                  False            True
# 419                 False                  False            True
#
# [4610 rows x 20 columns]

# %% [markdown]
# ## Filter data

# %%
data = raw_data.loc[raw_data["model"] == "HanSolo"]
data["horizon"] = data["horizon"].apply(lambda x: re.findall(r'\d+', x)[0])
data = data.astype({"horizon":"float64"})
data["forecast_date"] = pd.to_datetime(data["forecast_date"])
data = data.reset_index().drop("index", axis = 1)
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_12532/3892431281.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["horizon"] = data["horizon"].apply(lambda x: re.findall(r'\d+', x)[0])

# %% [markdown]
# # Dax evaluation

# %%
dax_data = data[data["target"] == "DAX"].copy()

# %%
for horizon in dax_data["horizon"].unique():
    dax_data.loc[dax_data["horizon"] == horizon, "forecast_date"] = dax_data.loc[dax_data["horizon"] == horizon, "forecast_date"] + timedelta(horizon)

# %%
def get_interval_plot(data):
    fig, axs = plt.subplots(figsize = (10,8))
    sns.lineplot(x = "forecast_date", y = "value", data = data, label = "True value")
    sns.lineplot(x = "forecast_date", y = "q0.5", data = data, label = "50% quantile")
    sns.lineplot(x = "forecast_date", y = "q0.025", data = data, color = "blue", label = "95% interval")
    sns.lineplot(x = "forecast_date", y = "q0.975", data = data, color = "blue")
    axs.fill_between(x = data["forecast_date"], y1 = data["q0.025"], y2 = data["q0.975"], alpha = 0.1, color = "blue")

    sns.lineplot(x = "forecast_date", y = "q0.25", data = data, color = "green", label = "50% interval")
    sns.lineplot(x = "forecast_date", y = "q0.75", data = data, color = "green")
    axs.fill_between(x = data["forecast_date"], y1 = data["q0.25"], y2 = data["q0.75"], alpha = 0.1, color = "green")
    axs.legend()

# %%
def get_error_plot(data):
    fig, axs = plt.subplots(figsize = (10,8))
    sns.lineplot(x = "forecast_date", y = "mean_qscore", data = data, hue = "scores_imputed")

# %%
get_interval_plot(dax_data)

# %%
get_error_plot(dax_data)

# %% [markdown]
# # Wind evaluation

# %%
wind_data = data[data["target"] == "wind"].copy()
for horizon in wind_data["horizon"].unique():
    wind_data.loc[wind_data["horizon"] == horizon, "forecast_date"] = wind_data.loc[wind_data["horizon"] == horizon, "forecast_date"] + timedelta(hours = horizon)

# %%
get_interval_plot(wind_data)

# %%
get_error_plot(wind_data)

# %% [markdown]
# # Temperature evaluation

# %%
temp_data = data[data["target"] == "temperature"].copy()
for horizon in temp_data["horizon"].unique():
    temp_data.loc[temp_data["horizon"] == horizon, "forecast_date"] = temp_data.loc[temp_data["horizon"] == horizon, "forecast_date"] + timedelta(hours = horizon)

# %%
get_interval_plot(temp_data)

# %%
get_error_plot(temp_data)
