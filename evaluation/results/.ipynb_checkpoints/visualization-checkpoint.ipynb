# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, datetime, timedelta
import re

# %% [markdown]
# ## Read weekly data

# %%
start_date = date(2021, 10 ,27)
raw_data = pd.read_csv("weekly/evaluation_{}.csv".format(start_date.strftime("%Y%m%d")))

# %%
new_date = start_date
while True:
    new_date = new_date + timedelta(7)
    try:
        raw_data = raw_data.append(pd.read_csv("weekly/evaluation_{}.csv".format(new_date.strftime("%Y%m%d"))))
    except:
        break

# %%
raw_data
# Out:
#                   model       target  horizon forecast_date    q0.025  \
# 0       GeneralGrievous          DAX    1 day    2021-10-27 -2.950348
# 1             AryaStark          DAX    1 day    2021-10-27 -2.294067
# 2              DougJudy          DAX    1 day    2021-10-27  0.098211
# 3           GinaLinetti          DAX    1 day    2021-10-27 -5.687000
# 4    CaptainRaymondHolt          DAX    1 day    2021-10-27 -2.502641
# ..                  ...          ...      ...           ...       ...
# 400           wind_EMOS  temperature  60 hour    2021-11-03       NaN
# 401      wind_benchmark  temperature  72 hour    2021-11-03       NaN
# 402           wind_EMOS  temperature  72 hour    2021-11-03       NaN
# 403      wind_benchmark  temperature  84 hour    2021-11-03       NaN
# 404           wind_EMOS  temperature  84 hour    2021-11-03       NaN
#
#         q0.25      q0.5     q0.75    q0.975      value  qscore_q0.025  \
# 0   -1.095254 -0.121883  0.851487  2.706582  -0.060375       0.144499
# 1   -0.422822  0.051950  0.540928  2.105637  -0.060375       0.111685
# 2    0.098224  0.098231  0.098238  0.098250  -0.060375       0.309243
# 3   -5.232000 -4.730000 -3.767000 -2.658000  -0.060375       0.281331
# 4   -0.423577  0.075881  0.674492  2.657910  -0.060375       0.122113
# ..        ...       ...       ...       ...        ...            ...
# 400       NaN       NaN       NaN       NaN   9.100000            NaN
# 401       NaN       NaN       NaN       NaN   7.500000            NaN
# 402       NaN       NaN       NaN       NaN   7.500000            NaN
# 403       NaN       NaN       NaN       NaN  10.600000            NaN
# 404       NaN       NaN       NaN       NaN  10.600000            NaN
#
#      qscore_q0.25  qscore_q0.5  qscore_q0.75  qscore_q0.975  mean_qscore  \
# 0        0.517439     0.061509      0.455931       0.138348     0.263545
# 1        0.181223     0.112325      0.300651       0.108301     0.162837
# 2        0.237898     0.158606      0.079306       0.007931     0.158597
# 3        2.585813     4.669625      5.559938       5.065369     3.632415
# 4        0.181601     0.136255      0.367433       0.135914     0.188664
# ..            ...          ...           ...            ...          ...
# 400           NaN          NaN           NaN            NaN     4.516309
# 401           NaN          NaN           NaN            NaN     2.724818
# 402           NaN          NaN           NaN            NaN     2.724818
# 403           NaN          NaN           NaN            NaN     5.697334
# 404           NaN          NaN           NaN            NaN     5.697334
#
#            ae interval_coverage_0.5 interval_coverage_0.95 scores_imputed
# 0    0.061509                  True                   True            NaN
# 1    0.112325                  True                   True            NaN
# 2    0.158606                 False                  False            NaN
# 3    4.669625                 False                  False            NaN
# 4    0.136255                  True                   True            NaN
# ..        ...                   ...                    ...            ...
# 400  5.255969                 False                  False           True
# 401  3.010843                 False                  False           True
# 402  3.010843                 False                  False           True
# 403  5.983358                 False                  False           True
# 404  5.983358                 False                  False           True
#
# [513 rows x 20 columns]

# %% [markdown]
# ## Filter data

# %%
data = raw_data.loc[raw_data["model"] == "HanSolo"]
data["horizon"] = data["horizon"].apply(lambda x: re.findall(r'\d+', x)[0])
data = data.astype({"horizon":"float64"})
data["forecast_date"] = pd.to_datetime(data["forecast_date"])
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_21368/2814652602.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["horizon"] = data["horizon"].apply(lambda x: re.findall(r'\d+', x)[0])

# %% [markdown]
# # Dax evaluation

# %%
dax_data = data[data["target"] == "DAX"].copy()

# %%
for horizon in dax_data["horizon"].unique():
    dax_data.loc[dax_data["horizon"] == horizon, "forecast_date"] = dax_data.loc[dax_data["horizon"] == horizon, "forecast_date"] + timedelta(horizon)

# %%
dax_data
# Out:
#       model target  horizon forecast_date    q0.025     q0.25      q0.5  \
# 17  HanSolo    DAX      1.0    2021-10-28 -1.842954 -0.568223  0.064408
# 31  HanSolo    DAX      2.0    2021-10-29 -2.319701 -0.950494  0.137721
# 58  HanSolo    DAX      5.0    2021-11-01 -3.290964 -0.835038  0.297649
# 72  HanSolo    DAX      6.0    2021-11-02 -3.881278 -1.112036  0.258100
# 90  HanSolo    DAX      7.0    2021-11-03 -3.935016 -1.042304  0.324122
# 5   HanSolo    DAX      1.0    2021-11-04 -3.209327 -0.578244  0.077734
# 23  HanSolo    DAX      2.0    2021-11-05 -2.549535 -0.627582  0.120788
# 59  HanSolo    DAX      5.0    2021-11-08 -5.519643 -0.766162  0.194377
# 86  HanSolo    DAX      6.0    2021-11-09 -4.952300 -0.869202  0.241294
# 96  HanSolo    DAX      7.0    2021-11-10 -7.461819 -0.550829  0.368222
#
#        q0.75    q0.975     value  qscore_q0.025  qscore_q0.25  qscore_q0.5  \
# 17  0.764962  2.687890 -0.060375       0.089129      0.253924     0.124782
# 31  0.860541  2.415874 -0.108554       0.110557      0.420970     0.246275
# 58  1.055945  4.553681  0.637728       0.196435      0.736383     0.340079
# 72  1.181688  4.836495  1.570712       0.272599      1.341374     1.312611
# 90  1.946898  3.338167       NaN            NaN           NaN          NaN
# 5   0.634355  1.567144  0.435579       0.182245      0.506912     0.357845
# 23  1.053213  2.207484  0.589612       0.156957      0.608597     0.468823
# 59  1.223096  2.203468  0.540761       0.303020      0.653461     0.346384
# 86  1.413107  3.013850  0.503052       0.272768      0.686127     0.261758
# 96  1.398829  4.058462       NaN            NaN           NaN          NaN
#
#     qscore_q0.75  qscore_q0.975  mean_qscore        ae interval_coverage_0.5  \
# 17      0.412668       0.137413     0.203583  0.124782                  True
# 31      0.484548       0.126221     0.277714  0.246275                  True
# 58      0.209108       0.195798     0.335561  0.340079                  True
# 72      0.583535       0.163289     0.734682  1.312611                 False
# 90           NaN            NaN          NaN       NaN                   NaN
# 5       0.099388       0.056578     0.240594  0.357845                  True
# 23      0.231800       0.080894     0.309414  0.468823                  True
# 59      0.341168       0.083135     0.345434  0.346384                  True
# 86      0.455028       0.125540     0.360244  0.261758                  True
# 96           NaN            NaN          NaN       NaN                   NaN
#
#    interval_coverage_0.95 scores_imputed
# 17                   True            NaN
# 31                   True            NaN
# 58                   True            NaN
# 72                   True            NaN
# 90                    NaN            NaN
# 5                    True          False
# 23                   True          False
# 59                   True          False
# 86                   True          False
# 96                    NaN          False

# %%
def get_interval_plot(data):
    fig, axs = plt.subplots(figsize = (10,8))
    sns.lineplot(x = "forecast_date", y = "value", data = data, label = "True value")
    sns.lineplot(x = "forecast_date", y = "q0.5", data = data, label = "50% quantile")
    sns.lineplot(x = "forecast_date", y = "q0.025", data = data, color = "blue", label = "95% interval")
    sns.lineplot(x = "forecast_date", y = "q0.975", data = data, color = "blue")
    axs.fill_between(x = data["forecast_date"], y1 = data["q0.025"], y2 = data["q0.975"], alpha = 0.1, color = "blue")

    sns.lineplot(x = "forecast_date", y = "q0.25", data = data, color = "green", label = "50% interval")
    sns.lineplot(x = "forecast_date", y = "q0.75", data = data, color = "green")
    axs.fill_between(x = data["forecast_date"], y1 = data["q0.25"], y2 = data["q0.75"], alpha = 0.1, color = "green")
    axs.legend()

# %%
def get_error_plot(data):
    fig, axs = plt.subplots(figsize = (10,8))
    sns.lineplot(x = "forecast_date", y = "mean_qscore", hue = "horizon", data = data)

# %%
get_interval_plot(dax_data)

# %%
get_error_plot(dax_data)

# %% [markdown]
# # Wind evaluation

# %%
wind_data = data[data["target"] == "wind"].copy()
for horizon in wind_data["horizon"].unique():
    wind_data.loc[wind_data["horizon"] == horizon, "forecast_date"] = wind_data.loc[wind_data["horizon"] == horizon, "forecast_date"] + timedelta(hours = horizon)

# %%
wind_data
# Out:
#        model target  horizon       forecast_date     q0.025      q0.25  \
# 114  HanSolo   wind     36.0 2021-11-04 12:00:00   9.008980  14.112084
# 141  HanSolo   wind     48.0 2021-11-05 00:00:00   8.901674  14.817027
# 168  HanSolo   wind     60.0 2021-11-05 12:00:00   9.045424  13.840762
# 195  HanSolo   wind     72.0 2021-11-06 00:00:00   7.066521  12.672591
# 222  HanSolo   wind     84.0 2021-11-06 12:00:00  10.816050  15.574940
#
#           q0.5      q0.75     q0.975  value  qscore_q0.025  qscore_q0.25  \
# 114  17.420645  20.307768  25.082108  17.28       0.413551      1.583958
# 141  17.945885  21.549999  28.956566  23.40       0.724916      4.291486
# 168  16.221087  18.463316  23.152771  17.28       0.411729      1.719619
# 195  14.257113  17.415918  25.860399  12.96       0.294674      0.143704
# 222  19.018330  21.133451  26.780411  19.44       0.431198      1.932530
#
#      qscore_q0.5  qscore_q0.75  qscore_q0.975  mean_qscore        ae  \
# 114     0.140645      1.513884       0.390105     0.808429  0.140645
# 141     5.454115      2.775001       0.277828     2.704669  5.454115
# 168     1.058913      0.591658       0.293639     0.815112  1.058913
# 195     1.297113      2.227959       0.645020     0.921694  1.297113
# 222     0.421670      0.846726       0.367021     0.799829  0.421670
#
#     interval_coverage_0.5 interval_coverage_0.95 scores_imputed
# 114                  True                   True          False
# 141                 False                   True          False
# 168                  True                   True          False
# 195                  True                   True          False
# 222                  True                   True          False

# %%
get_interval_plot(wind_data)

# %%
get_error_plot(wind_data)

# %% [markdown]
# # Temperature evaluation

# %%
temp_data = data[data["target"] == "temperature"].copy()
for horizon in temp_data["horizon"].unique():
    temp_data.loc[temp_data["horizon"] == horizon, "forecast_date"] = temp_data.loc[temp_data["horizon"] == horizon, "forecast_date"] + timedelta(hours = horizon)

# %%
temp_data
# Out:
#        model       target  horizon       forecast_date  q0.025  q0.25  \
# 239  HanSolo  temperature     36.0 2021-11-04 12:00:00    7.13   7.43
# 266  HanSolo  temperature     48.0 2021-11-05 00:00:00    6.78   7.40
# 293  HanSolo  temperature     60.0 2021-11-05 12:00:00    8.82   9.35
# 320  HanSolo  temperature     72.0 2021-11-06 00:00:00    5.03   6.47
# 347  HanSolo  temperature     84.0 2021-11-06 12:00:00    8.79  10.10
#
#           q0.5      q0.75     q0.975  value  qscore_q0.025  qscore_q0.25  \
# 239  13.423798  16.768173  23.142040    6.5         1.2285         1.395
# 266  10.875378  16.222228  26.412507    7.2         0.0210         0.300
# 293  12.639841  16.547695  23.995466    9.1         0.0140         0.375
# 320   8.298245  14.618607  26.664248    7.5         0.1235         0.515
# 347  11.814137  16.196138  24.547559   10.6         0.0905         0.250
#
#      qscore_q0.5  qscore_q0.75  qscore_q0.975  mean_qscore        ae  \
# 239     6.923798      5.134086       0.832102     3.102697  6.923798
# 266     3.675378      4.511114       0.960625     1.893623  3.675378
# 293     3.539841      3.723847       0.744773     1.679492  3.539841
# 320     0.798245      3.559303       0.958212     1.190852  0.798245
# 347     1.214137      2.798069       0.697378     1.010017  1.214137
#
#     interval_coverage_0.5 interval_coverage_0.95 scores_imputed
# 239                 False                  False          False
# 266                 False                   True          False
# 293                 False                   True          False
# 320                  True                   True          False
# 347                  True                   True          False

# %%
get_interval_plot(temp_data)

# %%
get_error_plot(temp_data)
