# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import date, datetime, timedelta
import re

# %% [markdown]
# ## Read weekly data

# %%
start_date = date(2021, 10 ,27)
raw_data = pd.read_csv("weekly/evaluation_{}.csv".format(start_date.strftime("%Y%m%d")))

# %%
new_date = start_date
while True:
    new_date = new_date + timedelta(7)
    try:
        raw_data = raw_data.append(pd.read_csv("weekly/evaluation_{}.csv".format(new_date.strftime("%Y%m%d"))))
    except:
        break

# %%
raw_data
# Out:
#                   model       target  horizon forecast_date    q0.025  \
# 0       GeneralGrievous          DAX    1 day    2021-10-27 -2.950348
# 1             AryaStark          DAX    1 day    2021-10-27 -2.294067
# 2              DougJudy          DAX    1 day    2021-10-27  0.098211
# 3           GinaLinetti          DAX    1 day    2021-10-27 -5.687000
# 4    CaptainRaymondHolt          DAX    1 day    2021-10-27 -2.502641
# ..                  ...          ...      ...           ...       ...
# 415           wind_EMOS  temperature  72 hour    2021-11-17       NaN
# 416       DAX_benchmark  temperature  84 hour    2021-11-17       NaN
# 417          RossGeller  temperature  84 hour    2021-11-17       NaN
# 418      wind_benchmark  temperature  84 hour    2021-11-17       NaN
# 419           wind_EMOS  temperature  84 hour    2021-11-17       NaN
#
#         q0.25      q0.5     q0.75    q0.975      value  qscore_q0.025  \
# 0   -1.095254 -0.121883  0.851487  2.706582  -0.060375       0.144499
# 1   -0.422822  0.051950  0.540928  2.105637  -0.060375       0.111685
# 2    0.098224  0.098231  0.098238  0.098250  -0.060375       0.309243
# 3   -5.232000 -4.730000 -3.767000 -2.658000  -0.060375       0.281331
# 4   -0.423577  0.075881  0.674492  2.657910  -0.060375       0.122113
# ..        ...       ...       ...       ...        ...            ...
# 415       NaN       NaN       NaN       NaN  11.900000            NaN
# 416       NaN       NaN       NaN       NaN  11.700000            NaN
# 417       NaN       NaN       NaN       NaN  11.700000            NaN
# 418       NaN       NaN       NaN       NaN  11.700000            NaN
# 419       NaN       NaN       NaN       NaN  11.700000            NaN
#
#      qscore_q0.25  qscore_q0.5  qscore_q0.75  qscore_q0.975  mean_qscore  \
# 0        0.517439     0.061509      0.455931       0.138348     0.263545
# 1        0.181223     0.112325      0.300651       0.108301     0.162837
# 2        0.237898     0.158606      0.079306       0.007931     0.158597
# 3        2.585813     4.669625      5.559938       5.065369     3.632415
# 4        0.181601     0.136255      0.367433       0.135914     0.188664
# ..            ...          ...           ...            ...          ...
# 415           NaN          NaN           NaN            NaN     4.092419
# 416           NaN          NaN           NaN            NaN     3.659880
# 417           NaN          NaN           NaN            NaN     3.659880
# 418           NaN          NaN           NaN            NaN     3.659880
# 419           NaN          NaN           NaN            NaN     3.659880
#
#            ae interval_coverage_0.5 interval_coverage_0.95 scores_imputed
# 0    0.061509                  True                   True            NaN
# 1    0.112325                  True                   True            NaN
# 2    0.158606                 False                  False            NaN
# 3    4.669625                 False                  False            NaN
# 4    0.136255                  True                   True            NaN
# ..        ...                   ...                    ...            ...
# 415  7.070000                 False                  False           True
# 416  6.377066                 False                  False           True
# 417  6.377066                 False                  False           True
# 418  6.377066                 False                  False           True
# 419  6.377066                 False                  False           True
#
# [1353 rows x 20 columns]

# %% [markdown]
# ## Filter data

# %%
data = raw_data.loc[raw_data["model"] == "HanSolo"]
data["horizon"] = data["horizon"].apply(lambda x: re.findall(r'\d+', x)[0])
data = data.astype({"horizon":"float64"})
data["forecast_date"] = pd.to_datetime(data["forecast_date"])
data = data.reset_index().drop("index", axis = 1)
# Out:
# C:\Users\chris\AppData\Local\Temp/ipykernel_20508/3892431281.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["horizon"] = data["horizon"].apply(lambda x: re.findall(r'\d+', x)[0])

# %% [markdown]
# # Dax evaluation

# %%
dax_data = data[data["target"] == "DAX"].copy()

# %%
for horizon in dax_data["horizon"].unique():
    dax_data.loc[dax_data["horizon"] == horizon, "forecast_date"] = dax_data.loc[dax_data["horizon"] == horizon, "forecast_date"] + timedelta(horizon)

# %%
dax_data
# Out:
#       model target  horizon forecast_date    q0.025     q0.25      q0.5  \
# 0   HanSolo    DAX      1.0    2021-10-28 -1.842954 -0.568223  0.064408
# 1   HanSolo    DAX      2.0    2021-10-29 -2.319701 -0.950494  0.137721
# 2   HanSolo    DAX      5.0    2021-11-01 -3.290964 -0.835038  0.297649
# 3   HanSolo    DAX      6.0    2021-11-02 -3.881278 -1.112036  0.258100
# 4   HanSolo    DAX      7.0    2021-11-03 -3.935016 -1.042304  0.324122
# 5   HanSolo    DAX      1.0    2021-11-04 -3.209327 -0.578244  0.077734
# 6   HanSolo    DAX      2.0    2021-11-05 -2.549535 -0.627582  0.120788
# 7   HanSolo    DAX      5.0    2021-11-08 -5.519643 -0.766162  0.194377
# 8   HanSolo    DAX      6.0    2021-11-09 -4.952300 -0.869202  0.241294
# 9   HanSolo    DAX      7.0    2021-11-10 -7.461819 -0.550829  0.368222
# 20  HanSolo    DAX      1.0    2021-11-11 -2.962476 -0.415850  0.073155
# 21  HanSolo    DAX      2.0    2021-11-12 -3.828928 -0.708453  0.142258
# 22  HanSolo    DAX      5.0    2021-11-15 -4.848476 -0.759549  0.147691
# 23  HanSolo    DAX      6.0    2021-11-16 -4.987350 -0.619476  0.215571
# 24  HanSolo    DAX      7.0    2021-11-17 -6.549297 -0.650865  0.345792
# 35  HanSolo    DAX      1.0    2021-11-18 -1.232744 -0.367333  0.068431
# 36  HanSolo    DAX      2.0    2021-11-19 -2.452496 -0.802519  0.164282
# 37  HanSolo    DAX      5.0    2021-11-22 -5.713077 -0.691311  0.260330
# 38  HanSolo    DAX      6.0    2021-11-23 -5.899470 -0.769606  0.208735
# 39  HanSolo    DAX      7.0    2021-11-24 -5.842459 -0.588018  0.338873
#
#        q0.75    q0.975     value  qscore_q0.025  qscore_q0.25  qscore_q0.5  \
# 0   0.764962  2.687890 -0.060375       0.089129      0.253924     0.124782
# 1   0.860541  2.415874 -0.108554       0.110557      0.420970     0.246275
# 2   1.055945  4.553681  0.637728       0.196435      0.736383     0.340079
# 3   1.181688  4.836495  1.570712       0.272599      1.341374     1.312611
# 4   1.946898  3.338167       NaN            NaN           NaN          NaN
# 5   0.634355  1.567144  0.435579       0.182245      0.506912     0.357845
# 6   1.053213  2.207484  0.589612       0.156957      0.608597     0.468823
# 7   1.223096  2.203468  0.540761       0.303020      0.653461     0.346384
# 8   1.413107  3.013850  0.503052       0.272768      0.686127     0.261758
# 9   1.398829  4.058462       NaN            NaN           NaN          NaN
# 20  0.681152  2.579503  0.095053       0.152876      0.255452     0.021899
# 21  1.114407  1.952095  0.163176       0.199605      0.435814     0.020918
# 22  1.159046  5.082759  0.501667       0.267507      0.630608     0.353976
# 23  1.558514  2.324880  1.114209       0.305078      0.866842     0.898638
# 24  1.343975  2.413723  1.134330       0.384181      0.892597     0.788538
# 35  0.620262  2.598099 -0.181071       0.052584      0.093131     0.249502
# 36  0.882279  2.014340 -0.562526       0.094498      0.119997     0.726808
# 37  1.134489  2.538511 -0.836908       0.243808      0.218395     1.097237
# 38  1.476497  2.612095 -1.951899       0.197379      1.773440     2.160634
# 39  1.530747  2.372614 -2.320339       0.176106      2.598482     2.659213
#
#     qscore_q0.75  qscore_q0.975  mean_qscore        ae interval_coverage_0.5  \
# 0       0.412668       0.137413     0.203583  0.124782                  True
# 1       0.484548       0.126221     0.277714  0.246275                  True
# 2       0.209108       0.195798     0.335561  0.340079                  True
# 3       0.583535       0.163289     0.734682  1.312611                 False
# 4            NaN            NaN          NaN       NaN                   NaN
# 5       0.099388       0.056578     0.240594  0.357845                  True
# 6       0.231800       0.080894     0.309414  0.468823                  True
# 7       0.341168       0.083135     0.345434  0.346384                  True
# 8       0.455028       0.125540     0.360244  0.261758                  True
# 9            NaN            NaN          NaN       NaN                   NaN
# 20      0.293049       0.124222     0.169500  0.021899                  True
# 21      0.475616       0.089446     0.244280  0.020918                  True
# 22      0.328689       0.229055     0.361967  0.353976                  True
# 23      0.222153       0.060534     0.470649  0.898638                  True
# 24      0.104823       0.063970     0.446822  0.788538                  True
# 35      0.400666       0.138958     0.186968  0.249502                  True
# 36      0.722403       0.128843     0.358510  0.726808                  True
# 37      0.985699       0.168771     0.542782  1.097237                 False
# 38      1.714198       0.228200     1.214770  2.160634                 False
# 39      1.925543       0.234648     1.518798  2.659213                 False
#
#    interval_coverage_0.95 scores_imputed
# 0                    True            NaN
# 1                    True            NaN
# 2                    True            NaN
# 3                    True            NaN
# 4                     NaN            NaN
# 5                    True          False
# 6                    True          False
# 7                    True          False
# 8                    True          False
# 9                     NaN          False
# 20                   True          False
# 21                   True          False
# 22                   True          False
# 23                   True          False
# 24                   True          False
# 35                   True          False
# 36                   True          False
# 37                   True          False
# 38                   True          False
# 39                   True          False

# %%
def get_interval_plot(data):
    fig, axs = plt.subplots(figsize = (10,8))
    sns.lineplot(x = "forecast_date", y = "value", data = data, label = "True value")
    sns.lineplot(x = "forecast_date", y = "q0.5", data = data, label = "50% quantile")
    sns.lineplot(x = "forecast_date", y = "q0.025", data = data, color = "blue", label = "95% interval")
    sns.lineplot(x = "forecast_date", y = "q0.975", data = data, color = "blue")
    axs.fill_between(x = data["forecast_date"], y1 = data["q0.025"], y2 = data["q0.975"], alpha = 0.1, color = "blue")

    sns.lineplot(x = "forecast_date", y = "q0.25", data = data, color = "green", label = "50% interval")
    sns.lineplot(x = "forecast_date", y = "q0.75", data = data, color = "green")
    axs.fill_between(x = data["forecast_date"], y1 = data["q0.25"], y2 = data["q0.75"], alpha = 0.1, color = "green")
    axs.legend()

# %%
def get_error_plot(data, per_horizon=False):
    fig, axs = plt.subplots(figsize = (10,8))
    if per_horizon == False:
        sns.lineplot(x = "forecast_date", y = "mean_qscore", data = data)
    else:
        sns.lineplot(x = "forecast_date", y = "mean_qscore", hue = "horizon", data = data)

# %%
get_interval_plot(dax_data)

# %%
get_error_plot(dax_data)

# %% [markdown]
# # Wind evaluation

# %%
data[data["target"] == "wind"]
# Out:
#       model target  horizon forecast_date     q0.025      q0.25       q0.5  \
# 10  HanSolo   wind     36.0    2021-11-03   9.008980  14.112084  17.420645
# 11  HanSolo   wind     48.0    2021-11-03   8.901674  14.817027  17.945885
# 12  HanSolo   wind     60.0    2021-11-03   9.045424  13.840762  16.221087
# 13  HanSolo   wind     72.0    2021-11-03   7.066521  12.672591  14.257113
# 14  HanSolo   wind     84.0    2021-11-03  10.816050  15.574940  19.018330
# 25  HanSolo   wind     36.0    2021-11-10   3.889780   7.935707   9.453829
# 26  HanSolo   wind     48.0    2021-11-10   0.872828   2.127781   4.402931
# 27  HanSolo   wind     60.0    2021-11-10   4.477252   8.904283  11.971659
# 28  HanSolo   wind     72.0    2021-11-10   3.809932   7.771947  10.143431
# 29  HanSolo   wind     84.0    2021-11-10   4.898277   9.537073  11.678784
# 40  HanSolo   wind     36.0    2021-11-17  11.925742  17.680944  20.867563
# 41  HanSolo   wind     48.0    2021-11-17  12.670548  17.427835  22.013285
# 42  HanSolo   wind     60.0    2021-11-17  14.719852  20.148254  23.892275
# 43  HanSolo   wind     72.0    2021-11-17  12.529921  16.714108  19.835861
# 44  HanSolo   wind     84.0    2021-11-17  11.949200  17.164938  19.329226
#
#         q0.75     q0.975  value  qscore_q0.025  qscore_q0.25  qscore_q0.5  \
# 10  20.307768  25.082108  17.28       0.413551      1.583958     0.140645
# 11  21.549999  28.956566  23.40       0.724916      4.291486     5.454115
# 12  18.463316  23.152771  17.28       0.411729      1.719619     1.058913
# 13  17.415918  25.860399  12.96       0.294674      0.143704     1.297113
# 14  21.133451  26.780411  19.44       0.431198      1.932530     0.421670
# 25  10.912843  15.043772   8.64       0.237511      0.352146     0.813829
# 26   7.325530  12.399355   7.92       0.352359      2.896110     3.517069
# 27  13.609918  17.085695  11.52       0.352137      1.307859     0.451659
# 28  12.570247  19.609003  12.60       0.439503      2.414027     2.456569
# 29  14.046896  22.080448   8.64       0.187086      1.345610     3.038784
# 40  22.865124  30.277832  18.72       0.339713      0.519528     2.147563
# 41  24.892141  34.104477  21.96       0.464473      2.266082     0.053285
# 42  27.016262  34.924213  21.60       0.344007      0.725873     2.292275
# 43  22.595770  30.654186  22.32       0.489504      2.802946     2.484139
# 44  23.221012  29.900661  18.36       0.320540      0.597531     0.969226
#
#     qscore_q0.75  qscore_q0.975  mean_qscore        ae interval_coverage_0.5  \
# 10      1.513884       0.390105     0.808429  0.140645                  True
# 11      2.775001       0.277828     2.704669  5.454115                 False
# 12      0.591658       0.293639     0.815112  1.058913                  True
# 13      2.227959       0.645020     0.921694  1.297113                  True
# 14      0.846726       0.367021     0.799829  0.421670                  True
# 25      1.136421       0.320189     0.572019  0.813829                  True
# 26      0.891705       0.223968     1.576242  3.517069                 False
# 27      1.044959       0.278285     0.686980  0.451659                  True
# 28      0.044630       0.350450     1.141036  2.456569                 False
# 29      2.703448       0.672022     1.589390  3.038784                 False
# 40      2.072562       0.577892     1.131451  2.147563                  True
# 41      1.466071       0.607224     0.971427  0.053285                  True
# 42      2.708131       0.666211     1.347299  2.292275                  True
# 43      0.137885       0.416709     1.266237  2.484139                  True
# 44      2.430506       0.577033     0.978967  0.969226                  True
#
#    interval_coverage_0.95 scores_imputed
# 10                   True          False
# 11                   True          False
# 12                   True          False
# 13                   True          False
# 14                   True          False
# 25                   True          False
# 26                   True          False
# 27                   True          False
# 28                   True          False
# 29                   True          False
# 40                   True          False
# 41                   True          False
# 42                   True          False
# 43                   True          False
# 44                   True          False

# %%
wind_data = data[data["target"] == "wind"].copy()
for horizon in wind_data["horizon"].unique():
    wind_data.loc[wind_data["horizon"] == horizon, "forecast_date"] = wind_data.loc[wind_data["horizon"] == horizon, "forecast_date"] + timedelta(hours = horizon)

# %%
get_interval_plot(wind_data)

# %%
get_error_plot(wind_data)

# %% [markdown]
# # Temperature evaluation

# %%
temp_data = data[data["target"] == "temperature"].copy()
for horizon in temp_data["horizon"].unique():
    temp_data.loc[temp_data["horizon"] == horizon, "forecast_date"] = temp_data.loc[temp_data["horizon"] == horizon, "forecast_date"] + timedelta(hours = horizon)

# %%
get_interval_plot(temp_data)

# %%
get_error_plot(temp_data)
